# %%
import pymongo
import time
from bson.timestamp import Timestamp
from bson.objectid import ObjectId
from datetime import datetime, timezone

import tensorflow as tf
import pandas as pd
import numpy as np

gpus = tf.config.experimental.list_physical_devices('GPU')
for gpu in gpus:
    tf.config.experimental.set_memory_growth(gpu, True)

# %%
uri = "mongodb+srv://Yeray:yerayTFG@cluster0.zecgf.mongodb.net/SmartMeter?retryWrites=true&w=majority&ssl=true"
client = pymongo.MongoClient(uri)
db = client.SmartMeter
    
# Obtenemos los datos de la colección
consumption_data = db['Consumption']

# %%
FILEPATH = "datasources/THC-id-17.csv"
df = pd.read_csv(FILEPATH, parse_dates=True)

# %%
df
# Out:
#                   datetime    id  value
# 0      2019-01-01 03:00:00  17.0  0.087
# 1      2019-01-01 03:15:00  17.0  0.100
# 2      2019-01-01 03:30:00  17.0  0.084
# 3      2019-01-01 03:45:00  17.0  0.057
# 4      2019-01-01 04:00:00  17.0  0.167
# ...                    ...   ...    ...
# 64588  2020-11-03 22:00:00  17.0  0.031
# 64589  2020-11-03 22:15:00  17.0  0.055
# 64590  2020-11-03 22:30:00  17.0  0.019
# 64591  2020-11-03 22:45:00  17.0  0.021
# 64592  2020-11-03 23:00:00  17.0  0.052
#
# [64593 rows x 3 columns]

# %%
df.loc[33528]['datetime']
# Out:
# '2019-12-16 09:00:00'

# %%
int(datetime.strptime(df.loc[33528]['datetime'], "%Y-%m-%d %H:%M:%S").timestamp())
# Out:
# 1576483200

# %%
lista = []
for i in range(len(df)):
    lista.append(
    {
      "metadata": { "meterId": int(df.iloc[i]['id']), "type": "consumption" },
      "timestamp": int(datetime.strptime(df.loc[i]['datetime'], "%Y-%m-%d %H:%M:%S").timestamp()),
      "value": df.iloc[i]['value']
    }
)

# %%
lista
# Out:
# [{'metadata': {'meterId': 17, 'type': 'consumption'},
#   'timestamp': 1546308000,
#   'value': 0.087},
#  {'metadata': {'meterId': 17, 'type': 'consumption'},
#   'timestamp': 1546308900,
#   'value': 0.1},
#  {'metadata': {'meterId': 17, 'type': 'consumption'},
#   'timestamp': 1546309800,
#   'value': 0.084},
#  {'metadata': {'meterId': 17, 'type': 'consumption'},
#   'timestamp': 1546310700,
#   'value': 0.057},
#  {'metadata': {'meterId': 17, 'type': 'consumption'},
#   'timestamp': 1546311600,
#   'value': 0.167},
#  {'metadata': {'meterId': 17, 'type': 'consumption'},
#   'timestamp': 1546312500,
#   'value': 0.053},
#  {'metadata': {'meterId': 17, 'type': 'consumption'},
#   'timestamp': 1546313400,
#   'value': 0.057},
#  {'metadata': {'meterId': 17, 'type': 'consumption'},
#   'timestamp': 1546314300,
#   'value': 0.058},
#  {'metadata': {'meterId': 17, 'type': 'consumption'},
#   'timestamp': 1546315200,
#   'value': 0.038},
# ...

# %%
consumption_data.insert_many(lista)
